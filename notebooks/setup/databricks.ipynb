# %% [markdown]
# ## ⚙️ Databricks Setup

# %%
# Create a Catalog
spark.sql(f"CREATE CATALOG IF NOT EXISTS sandbox_prd")

# %%
# Create a Database
# Bronze
spark.sql(f"CREATE DATABASE IF NOT EXISTS sandbox_prd.bronze_layer")
# Silver
spark.sql(f"CREATE DATABASE IF NOT EXISTS sandbox_prd.silver_layer")

# %%
# Define constants for table names
PATH_ORIGIN = "/Volumes/sandbox_prd/raw_layer/files/spotify/me/extended/" # REPLACE WITH YOUR OWN PATH 
NAME_TABLE_BRONZE = "sandbox_prd.bronze_layer.streaming_history_user_spotify"
NAME_TABLE_SILVER = "sandbox_prd.silver_layer.streaming_history_user_spotify"
