# %%
import pandas as pd
import glob
# read .json
files = glob.glob("../data/extended/Streaming_History_*.json")
dfs = [pd.read_json(file) for file in files]
df = pd.concat(dfs, ignore_index=True)
teste= spark.createDataFrame(df)
display(teste)
